# %% [markdown]
# # Fit Rankine, Holland, Willoughby and Chavas profiles on SAR data
# Note that so far the Rmax is searched in the first 200km around the TC center (in the code this impacts how the functions are initialized, but also when the curves are plot (on the smaller scale graph).
#
# For the fitting, we constrain Rmax > 5km which works well for a lot of TCs.
#
# In the papers of Holland, Willoughby and Chavas, the wind used is the tangential wind (same for Rankine).
#
# TODO:
#
# ==> Which profiles work when? etc...

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

from scipy.interpolate import griddata
from scipy.optimize import curve_fit

import glob

import functions as f

# %%
### PATHS
# dir_path = '/home/arthur/data/cyclobs/rotated_files/'
dir_path = '/home/arthur/data/cyclobs/rotated_files/clean_dataset/'
all_data = glob.glob(dir_path + "*.nc")
print("Total number of files:", len(all_data))
# Savepath to be modified directly in the function

### PARAMS
PARAMS = {
    'r_window_len':          501,  # Scale for radius (km)
    'rmax_window':           300,  # Window in whick we look for Rmax (e.g [0, 200km])
    'chavas_vfit':           17,
    'rank_hol_will_vmin':    True, # Uses Vmin as a free parameter if True. If False, Vmin = 0
    'chavas_vmin':           False, # Translates the profile from Vmin if True
    
    'r_Rmax_axis':           True, # If True, uses r* = r/Rmax as x-axis
    'v_Vmax_axis':           True, # If True, uses V* = V/Vmax as y-axis
    'r_Rmax_scale':          16.,
    'r_Rmax_num_pts':        321,
    
    'use_curve_fit':         True,
    'tangential_wind_speed': True, # If False, total wind speed is used
    'print_values':          False, 
    
    'save_dir':              "/home/arthur/results/windProfiles/test12/",
    'save_comparison':       True,
    'save_scatter':          False
    }
# Out:
# Total number of files: 322

# %%
# INITIALIZE DATA STRUCTURE
INI = {           # Initial values
    'Rankine':    [], # x, alpha, Vmin, Rmax
    'Holland':    [], # Lat, pn, pc, Vmin, Rmax, Vmax
    'Willoughby': [], # n, X1, Vmin, Rmax, Vmax
    'Chavas':     []  # Vmax, Vmin, Rfit, Vfit, fcor, Cdvary, Cd, w_cool, CkCdvary, CkCd, eye_adj, alpha_eye
    } 
FIT = {           # Fit values
    'Rankine':    [], # x, alpha, Vmin, Rmax
    'Holland':    [], # Lat, pn, pc, Vmin, Rmax, Vmax
    'Willoughby': [], # n, X1, Vmin, Rmax, Vmax
    'Chavas':     []  # rr, VV, rmax, r0, rmerge, Vmerge
    }
# GAP WITH OBSERVATIONS
NB_CAT    = [None] * 6
DIFF      = [None] * 6
RMAX_OBS  = [None] * 6
RMAX_FIT  = [None] * 6
VMAX_OBS  = [None] * 6
VMAX_FIT  = [None] * 6
FIT_PARAMS= [None] * 6
r_axis_length = PARAMS['r_window_len']
if PARAMS['r_Rmax_axis']:
    r_axis_length = PARAMS['r_Rmax_num_pts']
for i in range(6):
    # DIFF[0] = Storm
    # DIFF[i] = Cat. i
    DIFF[i] = {
    'Rankine':    np.empty((0,0)),
    'Holland':    np.empty((0,0)),
    'Willoughby': np.empty((0,0)),
    'Chavas':     np.empty((0,0))
    }
    NB_CAT[i] = {
    'Rank-Hol-Will': np.empty((0,0)),
    'Chavas':        np.empty((0,0))
    }
    RMAX_OBS[i] = []
    RMAX_FIT[i] = {
    'Rankine':    [],
    'Holland':    [],
    'Willoughby': [],
    'Chavas':     [] 
    }
    VMAX_OBS[i] = []
    VMAX_FIT[i] = {
    'Rankine':    [],
    'Holland':    [],
    'Willoughby': [],
    'Chavas':     [] 
    }
    FIT_PARAMS[i] = {
    'Rankine':    [],
    'Holland':    [],
    'Willoughby': [],
    'Chavas':     [] 
    }

# %%
def calculate_diff_by_cat(cat, Rmax, Vmax, r, spdm, INI, FIT, DIFF, NB_CAT, PARAMS):   
    # Compute fitted profiles
    V_rankine              = f.rankine_profile(r, *FIT['Rankine'])
    V_holland              = f.holland_profile(r, *FIT['Holland'])
    V_willoughby_no_smooth = f.willoughby_profile_no_smooth(r, *FIT['Willoughby'])
    V_chavas               = FIT['Chavas'][1]         # Different from other profiles: here V_chavas has already been computed before, and is stored in FIT['Chavas'][1]
    r_chavas               = FIT['Chavas'][0] / 1000. # Convert from m to km 
    
    # Re-scale Chavas
    lower_bound   = np.argmax(r_chavas >= r[0] - 0.5) # find the index i so that r_chavas[i] = r[0], i.e to translate Cavas if r[0] = 5km for instance
    r_chavas      = r_chavas[lower_bound:]
    V_chavas      = V_chavas[lower_bound:]
    # TODO: use proper interpolation to do what follows
    ind_chavas500 = [np.argwhere(r_chavas >= i)[0] for i in range(0, min(len(r), int(r_chavas[-1])))] # compute the indices of r = 0, 1, 2, ... ==> e.g convert [0.8, 0.9, 0.9, 1.1, 1.2, 1.5, 1.7, 1.9, 2.1, 2.3] to [0, 3, 8]
    ind_chavas500 = [int(i) for i in ind_chavas500]
    V_chavas500   = [V_chavas[i] for i in ind_chavas500]
    
    # Initialize NB_CAT for each profile
    nbcat_rank_hol_will = [1] * len(spdm)
    nbcat_chavas        = [1] * len(V_chavas500)
    nbcat_chavas        = np.concatenate((nbcat_chavas, [0] * (PARAMS['r_window_len'] - len(V_chavas500))), axis=0)
    if len(V_chavas500) < len(spdm):
        V_chavas500 = np.concatenate((V_chavas500, spdm[len(V_chavas500):]), axis=0)
        
    # Compute difference between obs and profile
    diff_rankine = np.subtract(V_rankine, spdm)
    diff_holland = np.subtract(V_holland, spdm)
    diff_willou  = np.subtract(V_willoughby_no_smooth, spdm)
    diff_chavas  = np.subtract(V_chavas500, spdm)
    if PARAMS['r_window_len'] - len(spdm) > 0:
        diff_rankine_filled = np.concatenate((diff_rankine, [0] * (PARAMS['r_window_len'] - len(spdm))), axis=0)
        diff_holland_filled = np.concatenate((diff_holland, [0] * (PARAMS['r_window_len'] - len(spdm))), axis=0)
        diff_willou_filled  = np.concatenate((diff_willou,  [0] * (PARAMS['r_window_len'] - len(spdm))), axis=0)
        diff_chavas_filled  = np.concatenate((diff_chavas,  [0] * (PARAMS['r_window_len'] - len(spdm))), axis=0)
        nbcat_rank_hol_will_filled = np.concatenate((nbcat_rank_hol_will, [0] * (PARAMS['r_window_len'] - len(spdm))), axis=0)
    
    # Normalize by Vmax to obtain V* = V/Vmax
    if PARAMS['v_Vmax_axis']:
        diff_rankine = np.divide(diff_rankine, Vmax)
        diff_holland = np.divide(diff_holland, Vmax)
        diff_willou  = np.divide(diff_willou, Vmax)
        diff_chavas  = np.divide(diff_chavas, Vmax)
        if PARAMS['r_Rmax_axis'] == False and PARAMS['r_window_len'] - len(spdm) > 0:
            diff_rankine_filled = np.divide(diff_rankine_filled, Vmax)
            diff_holland_filled = np.divide(diff_holland_filled, Vmax)
            diff_willou_filled  = np.divide(diff_willou_filled, Vmax)
            diff_chavas_filled  = np.divide(diff_chavas_filled, Vmax)
        
    # Determine the cat. index
    cat = np.array(cat)
    if cat == 'storm' or cat == 'dep':
        i = 0
    else: # then it's 'cat-0', 1, ..., or 5
        i = int(str(cat)[-1])
    
    # Update DIFF and NB_CAT
    r_star = np.linspace(0., PARAMS['r_Rmax_scale'], num=PARAMS['r_Rmax_num_pts']) # axis of reference
    r_Rmax = np.divide(r, Rmax)
    if DIFF[i]['Rankine'].shape == (0, 0): # else we will use np.append()
        DIFF[i]['Rankine']    = np.expand_dims(np.interp(r_star, r_Rmax, diff_rankine), axis=0)
        DIFF[i]['Holland']    = np.expand_dims(np.interp(r_star, r_Rmax, diff_holland), axis=0)
        DIFF[i]['Willoughby'] = np.expand_dims(np.interp(r_star, r_Rmax, diff_willou), axis=0)
        DIFF[i]['Chavas']     = np.expand_dims(np.interp(r_star, r_Rmax, diff_chavas), axis=0)            
    else:
        DIFF[i]['Rankine'] = np.append(DIFF[i]['Rankine'], np.expand_dims(np.interp(r_star, r_Rmax, diff_rankine), axis=0), axis=0) # CAVEAT: if r[500]/Rmax < 16 then np.interp() still fills the vector with the value of diff_rankine[-1]
        DIFF[i]['Holland'] = np.append(DIFF[i]['Holland'], np.expand_dims(np.interp(r_star, r_Rmax, diff_holland), axis=0), axis=0)
        DIFF[i]['Willoughby'] = np.append(DIFF[i]['Willoughby'], np.expand_dims(np.interp(r_star, r_Rmax, diff_willou), axis=0), axis=0)
        DIFF[i]['Chavas'] = np.append(DIFF[i]['Chavas'], np.expand_dims(np.interp(r_star, r_Rmax, diff_chavas), axis=0), axis=0)
    if NB_CAT[i]['Rank-Hol-Will'].shape == (0, 0): # else we will use np.append()
        NB_CAT[i]['Rank-Hol-Will'] = np.expand_dims(np.interp(r_star, r_Rmax, nbcat_rank_hol_will), axis=0)
        NB_CAT[i]['Chavas']        = np.expand_dims(np.interp(r_star, r_Rmax, nbcat_chavas[:len(r_Rmax)]), axis=0)
    else:
        NB_CAT[i]['Rank-Hol-Will'] = np.append(NB_CAT[i]['Rank-Hol-Will'], np.expand_dims(np.interp(r_star, r_Rmax, nbcat_rank_hol_will), axis=0), axis=0)
        NB_CAT[i]['Chavas']        = np.append(NB_CAT[i]['Chavas'], np.expand_dims(np.interp(r_star, r_Rmax, nbcat_chavas[:len(r_Rmax)]), axis=0), axis=0)
       
    return DIFF, NB_CAT

'''
def get_mean_std(x, n):
    mean = np.divide(np.sum(x, axis=0), np.expand_dims(n, axis=0))
    gap  = (x - mean) ** 2
    var  = np.divide(np.sum(gap, axis=0), n)
    std  = np.sqrt(var)
    return mean, std
'''

def get_mean_std(x, n):
    masked = np.ma.masked_where(n == 0, x)
    mean   = np.ma.mean(masked, axis=0)
    std    = np.ma.std(masked, axis=0)
    return mean, std

def plot_comp_by_cat(DIFF, NB_CAT, PARAMS):
    # Initialize radius
    xlabel = 'r (km)'
    ylabel = 'Wind speed mean difference (m/s)'
    if PARAMS['r_Rmax_axis']:
        r      = np.linspace(0., PARAMS['r_Rmax_scale'], num=PARAMS['r_Rmax_num_pts']) # axis of reference
        xlabel = 'r* = r/Rmax'
    else:   
        r      = np.arange(501)
    if PARAMS['v_Vmax_axis']:
        ylabel = 'V* = V/Vmax mean difference'
    
    # Define figure attributes
    filename = f.get_filename('all_profiles_comparison_by_category', PARAMS)
    fig = plt.figure(figsize=(25, 35))
    plt.suptitle("Mean difference between SAR wind speed and common parametric profiles", fontsize=18)
    COLORS = {
        'Willoughby': 'orchid',
        'Chavas':     'forestgreen'
    }
    subtitles = ['Storm', 'Cat.1', 'Cat.2', 'Cat.3', 'Cat.4', 'Cat.5']
    
    # Print TC number in each cat:
    print("Number of TCs in each categories:")
    print("Storm:  ", int(np.max(np.sum(NB_CAT[0]['Chavas'], axis=0))))
    for i in range(1, 6):
        print("Cat.", i, ":", int(np.max(np.sum(NB_CAT[i]['Rank-Hol-Will'], axis=0))))
    
    # Plot curves
    for i in range(6):
        RMSE = {
        'Willoughby': 0.,
        'Chavas':     0. 
        }
        ax = fig.add_subplot(6, 1, i + 1)
        plt.gca().set_title(subtitles[i], fontsize=16)
        for profile in ['Willoughby', 'Chavas']:
            if profile == 'Chavas':
                mean_diff, std_diff = get_mean_std(DIFF[i][profile], NB_CAT[i][profile])
            else:
                mean_diff, std_diff = get_mean_std(DIFF[i][profile], NB_CAT[i]['Rank-Hol-Will'])
            plt.plot(r, mean_diff, color=COLORS[profile], label=profile)
            plt.fill_between(r, mean_diff - std_diff, mean_diff + std_diff,
                            facecolor = COLORS[profile],
                            color     = COLORS[profile],
                            alpha     = 0.2
                            )
            
            # Compute and plot RMSEs
            RMSE[profile] = f.rmse(mean_diff, [0.] * len(mean_diff)) * 100
        plt.text(0.4, 0.78, 'Mean gap (percentage of Vmax): \nWilloughby = {:.2f}   Chavas = {:.2f}'.format(RMSE['Willoughby'], RMSE['Chavas']), fontsize=14, transform = ax.transAxes, bbox=dict(facecolor='white', edgecolor='k', pad=10.0))
        
        # Set legends
        plt.xlabel(xlabel, fontsize=18)
        plt.ylabel(ylabel, fontsize=18)
        ax.set_xticks(np.arange(0, PARAMS['r_Rmax_scale'], 1))
        if PARAMS['v_Vmax_axis']:
                ax.set_ylim(-0.3, 0.7)
        plt.legend();plt.grid()
    
    # Save figure
    if PARAMS['save_comparison']:
        plt.savefig(PARAMS['save_dir'] + filename)
    else:
        plt.show() # f.
        
    return None

# %%
### ======================= WITHOUT QUADRANT ======================= 
# FIT AND PRINT ALL THE PROFILES ON ALL THE DATA
i   = 0
for file in all_data[:20]: # Set minimum 20
    i += 1
    print(i, "=>    ", file)
    # Open file and compute mean wind speed
    ds      = xr.open_dataset(file)
    if PARAMS['tangential_wind_speed']:
        spdm = f.compute_mean_tangential_wind_spd(ds, r_window_len=PARAMS['r_window_len']) # TANGENTIAL WIND SPEED
    else:
        spdm = f.compute_mean_wind_spd(ds, r_window_len=PARAMS['r_window_len'])            # TOTAL WIND SPEED
    
    # Debug
    if 1 == 0: # DEBUG
        f.print_ds(ds)
        f.print_spd(ds)
        print(spdm)
    
    # Initialize and fit profile
    r, spdm, first_valid_index = f.initialize_radius(spdm)
    
    INI['Rankine']    = f.initialize_rankine(spdm, x=0.5, alpha=1.,                                PARAMS=PARAMS)
    INI['Holland']    = f.initialize_holland(spdm, Lat=np.float64(ds['lat_ref']), pn=1005, pc=950, PARAMS=PARAMS)
    INI['Willoughby'] = f.initialize_willoughby(spdm, n=1.,                                        PARAMS=PARAMS)
    INI['Chavas']     = f.initialize_chavas(spdm, Lat=np.float64(ds['lat_ref']),                   PARAMS=PARAMS)
    
    FIT['Rankine']    = f.fit_rankine(r, spdm, *INI['Rankine'],                 PARAMS=PARAMS)
    FIT['Holland']    = f.fit_holland(r, spdm, *INI['Holland'],                 PARAMS=PARAMS)
    FIT['Willoughby'] = f.fit_willoughby_no_smooth(r, spdm, *INI['Willoughby'], PARAMS=PARAMS)
    FIT['Chavas']     = f.fit_chavas(*INI['Chavas'],                            PARAMS=PARAMS)
    
    Rmax, Vmax = INI['Holland'][4], INI['Holland'][5]
    
    # Comparison by category, function of r_star
    DIFF, NB_CAT = calculate_diff_by_cat(ds['current_category'], Rmax, Vmax, r, spdm, INI, FIT, DIFF, NB_CAT, PARAMS)
    # Compute mean fitted parameters by category
    FIT_PARAMS   = f.calculate_fitted_params_by_cat(ds['current_category'], FIT, FIT_PARAMS, PARAMS)
    # Scater-plots
    RMAX_OBS, RMAX_FIT, VMAX_OBS, VMAX_FIT = f.add_to_scatter_list(ds['current_category'], r, Rmax, Vmax, FIT, RMAX_OBS, RMAX_FIT, VMAX_OBS, VMAX_FIT, PARAMS)

### Plot the comparison
plot_comp_by_cat(DIFF, NB_CAT, PARAMS)
# f.plot_fitted_params_by_cat(FIT_PARAMS, PARAMS)
# f.plot_scatter_rmax(RMAX_OBS, RMAX_FIT, PARAMS)
# f.plot_scatter_vmax(VMAX_OBS, VMAX_FIT, PARAMS)
# Out:
# 1 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180902t143708-20180902t143912-000003-01720F_ll_gd_rotated.nc
# /home/arthur/scripts/windProfiles/symmetric/functions.py:275: RuntimeWarning: divide by zero encountered in true_divide
#   V_ER11 = (1. / rr_ER11) * (Vmax * rmax + .5 * fcor * rmax ** 2) * ((2 * (rr_ER11 / rmax) ** 2) / (2 - CkCd + CkCd * (rr_ER11 / rmax) ** 2)) ** (1 / (2 - CkCd)) - .5 * fcor * rr_ER11
# /home/arthur/scripts/windProfiles/symmetric/functions.py:275: RuntimeWarning: invalid value encountered in multiply
#   V_ER11 = (1. / rr_ER11) * (Vmax * rmax + .5 * fcor * rmax ** 2) * ((2 * (rr_ER11 / rmax) ** 2) / (2 - CkCd + CkCd * (rr_ER11 / rmax) ** 2)) ** (1 / (2 - CkCd)) - .5 * fcor * rr_ER11
# /home/arthur/scripts/windProfiles/symmetric/functions.py:189: RuntimeWarning: invalid value encountered in true_divide
#   VV = (Mm / rmax) * (MMfracMm / rrfracrm) - .5 * fcor * rmax * rrfracrm #[ms-1]
# 2 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150601t015945-20150601t020101-00003-BDBF8_ll_gd_rotated.nc
# 3 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160827t092124-20160827t092414-000003-014249_ll_gd_rotated.nc
# 4 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20170207t015253-20170207t015558-000003-018D33_ll_gd_rotated.nc
# 5 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150509t232412-20150509t232525-00003-E0BD7_ll_gd_rotated.nc
# /home/arthur/scripts/windProfiles/symmetric/functions.py:640: RuntimeWarning: Mean of empty slice
#   spdm   = np.nanmean(spd, axis=0)
# 6 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181002t211106-20181002t211310-000003-029DF5_ll_gd_rotated.nc
# 7 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170504t071401-20170504t071505-000003-01B35C_ll_gd_rotated.nc
# 8 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20191106t194803-20191106t195007-000003-02377F_ll_gd_rotated.nc
# 9 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170921t224421-20170921t224626-000003-01F204_ll_gd_rotated.nc
# 10 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190428t122321-20190428t122602-000003-01E172_ll_gd_rotated.nc
# 11 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180303t150001-20180303t150306-000003-011DA1_ll_gd_rotated.nc
# 12 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200902t084047-20200902t084419-00003-1B372_ll_gd_rotated.nc
# 13 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201026t221102-20201026t221307-000003-041438_ll_gd_rotated.nc
# 14 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170907t102951-20170907t103127-000003-01EB76_ll_gd_rotated.nc
# 15 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20191231t144416-20191231t144620-000003-03813D_ll_gd_rotated.nc
# 16 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190330t135323-20190330t135509-000003-01D369_ll_gd_rotated.nc
# 17 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200825t213536-20200825t213810-00003-15E0D_ll_gd_rotated.nc
# 18 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150805t211206-20150805t211322-00003-E0BF1_ll_gd_rotated.nc
# 19 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180201t132219-20180201t132527-000003-022E2F_ll_gd_rotated.nc
# 20 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160827t205158-20160827t205454-000003-014285_ll_gd_rotated.nc
# 21 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20191114t201229-20191114t201344-00003-2B713_ll_gd_rotated.nc
# 22 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20191011t205230-20191011t205434-000003-03587A_ll_gd_rotated.nc
# 23 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180808t041303-20180808t041507-000003-0283BF_ll_gd_rotated.nc
# 24 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181222t002236-20181222t002440-000003-01A498_ll_gd_rotated.nc
# 25 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20141105t203222-20141105t203338-00003-E41DA_ll_gd_rotated.nc
# 26 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20161008t102403-20161008t102520-00003-E08D0_ll_gd_rotated.nc
# 27 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181110t020115-20181110t020319-000003-02B0A7_ll_gd_rotated.nc
# 28 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20200725t034755-20200725t035002-000003-03E50E_ll_gd_rotated.nc
# 29 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20201031t212858-20201031t213128-000003-02DBDB_ll_gd_rotated.nc
# 30 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150515t083749-20150515t083905-00003-E0BD9_ll_gd_rotated.nc
# 31 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180823t043704-20180823t043913-000003-028AD1_ll_gd_rotated.nc
# 32 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180807t154512-20180807t154628-00003-07134_ll_gd_rotated.nc
# 33 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150801t072303-20150801t072419-00003-E0BEB_ll_gd_rotated.nc
# 34 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180818t080233-20180818t080350-00003-0EA59_ll_gd_rotated.nc
# 35 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20141103t131130-20141103t131246-00003-E41DD_ll_gd_rotated.nc
# 36 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20171021t092057-20171021t092213-00003-BDC95_ll_gd_rotated.nc
# 37 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150602t135643-20150602t135759-00003-2B6FE_ll_gd_rotated.nc
# 38 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20191119t095826-20191119t095943-000003-023D71_ll_gd_rotated.nc
# 39 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20191012t084028-20191012t084212-000003-022BD1_ll_gd_rotated.nc
# 40 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180825t163219-20180825t163334-000003-028C00_ll_gd_rotated.nc
# 41 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150902t201620-20150902t201736-00003-E0BF3_ll_gd_rotated.nc
# 42 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170918t095058-20170918t095152-000003-01F075_ll_gd_rotated.nc
# 43 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150829t034258-20150829t034658-00003-68AC9_ll_gd_rotated.nc
# 44 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170730t080121-20170730t080401-00003-BDC5F_ll_gd_rotated.nc
# 45 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20191207t023226-20191207t023357-000003-0374DF_ll_gd_rotated.nc
# 46 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20201225t014342-20201225t014552-000003-02F4F5_ll_gd_rotated.nc
# 47 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150801t194958-20150801t195113-00003-562DD_ll_gd_rotated.nc
# 48 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150827t170957-20150827t171231-00003-68AD9_ll_gd_rotated.nc
# 49 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170918t221759-20170918t222029-000003-01F0A9_ll_gd_rotated.nc
# 50 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180928t093504-20180928t093708-000003-029BC7_ll_gd_rotated.nc
# 51 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180806t011151-20180806t011245-000003-0282CD_ll_gd_rotated.nc
# 52 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180316t204737-20180316t204852-000003-024251_ll_gd_rotated.nc
# 53 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170802t185532-20170802t185648-00003-0B25E_ll_gd_rotated.nc
# 54 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180206t131732-20180206t132210-00003-873F3_ll_gd_rotated.nc
# 55 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20201009t120643-20201009t120826-000003-040B68_ll_gd_rotated.nc
# 56 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140803t143514-20140803t143630-00003-E41BC_ll_gd_rotated.nc
# 57 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180201t002120-20180201t002425-000003-010EF2_ll_gd_rotated.nc
# 58 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20190920t130548-20190920t130734-000003-034DBE_ll_gd_rotated.nc
# 59 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20200316t020118-20200316t020322-000003-03A788_ll_gd_rotated.nc
# 60 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160826t211505-20160826t211809-000003-01420D_ll_gd_rotated.nc
# 61 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201027t103902-20201027t104036-000003-04147D_ll_gd_rotated.nc
# 62 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150510t215025-20150510t215141-00003-BDBE0_ll_gd_rotated.nc
# 63 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180810t165606-20180810t165822-000003-0167B7_ll_gd_rotated.nc
# 64 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181013t071546-20181013t071851-000003-02A2E9_ll_gd_rotated.nc
# 65 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140703t111356-20140703t111450-00003-E41BB_ll_gd_rotated.nc
# 66 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20190914t231126-20190914t231306-000003-034AF8_ll_gd_rotated.nc
# 67 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201002t022254-20201002t022409-00003-3268A_ll_gd_rotated.nc
# 68 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180908t161305-20180908t161509-000003-029283_ll_gd_rotated.nc
# 69 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20161015t202838-20161015t202954-00003-562F5_ll_gd_rotated.nc
# 70 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190426t233222-20190426t233402-000003-01E0B1_ll_gd_rotated.nc
# 71 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180824t084311-20180824t084426-000003-028B5C_ll_gd_rotated.nc
# 72 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180724t205502-20180724t205706-000003-027D46_ll_gd_rotated.nc
# 73 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20191121t220435-20191121t220530-000003-036D35_ll_gd_rotated.nc
# 74 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190614t133247-20190614t133442-000003-01F6A9_ll_gd_rotated.nc
# 75 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170729t083209-20170729t083300-00003-0240A_ll_gd_rotated.nc
# 76 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20161105t201351-20161105t201507-00003-E08E1_ll_gd_rotated.nc
# 77 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20151003t104333-20151003t104734-00003-BDC2F_ll_gd_rotated.nc
# 78 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20190801t143241-20190801t143612-00003-0370B_ll_gd_rotated.nc
# 79 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160905t103205-20160905t103509-000003-0146B3_ll_gd_rotated.nc
# 80 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200726t161050-20200726t161314-00003-009C8_ll_gd_rotated.nc
# 81 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201030t092540-20201030t092711-000003-0415F8_ll_gd_rotated.nc
# 82 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181003t053409-20181003t053714-000003-017FB4_ll_gd_rotated.nc
# 83 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20191030t015123-20191030t015337-000003-0233DE_ll_gd_rotated.nc
# 84 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20200728t171208-20200728t171335-000003-02B09D_ll_gd_rotated.nc
# 85 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160724t140547-20160724t140702-00003-E08D0_ll_gd_rotated.nc
# 86 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180807t154302-20180807t154506-000003-028386_ll_gd_rotated.nc
# 87 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180913t221855-20180913t222010-000003-0294F7_ll_gd_rotated.nc
# 88 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180925t211906-20180925t212211-000003-029AA3_ll_gd_rotated.nc
# 89 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190214t182852-20190214t182957-000003-02E348_ll_gd_rotated.nc
# 90 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181003t134006-20181003t134210-000003-029E52_ll_gd_rotated.nc
# 91 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150514t195522-20150514t195638-00003-E0BD7_ll_gd_rotated.nc
# 92 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190218t184446-20190218t184711-000003-01C08C_ll_gd_rotated.nc
# 93 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20201006t204525-20201006t204640-000003-02D075_ll_gd_rotated.nc
# 94 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150904t181517-20150904t181633-00003-E0C03_ll_gd_rotated.nc
# 95 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190929t210610-20190929t210814-000003-02261A_ll_gd_rotated.nc
# 96 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150903t044155-20150903t044311-00003-E0C03_ll_gd_rotated.nc
# 97 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180805t150354-20180805t150510-00003-05A2E_ll_gd_rotated.nc
# 98 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180727t082106-20180727t082414-000003-016145_ll_gd_rotated.nc
# 99 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180725t204505-20180725t204810-000003-016099_ll_gd_rotated.nc
# 100 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181005t215009-20181005t215213-000003-0180E1_ll_gd_rotated.nc
# 101 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180818t204359-20180818t204703-000003-016B56_ll_gd_rotated.nc
# 102 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160830t144512-20160830t144658-000003-0143DB_ll_gd_rotated.nc
# 103 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170215t161335-20170215t161522-000003-019126_ll_gd_rotated.nc
# 104 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181004t020906-20181004t021111-000003-029E91_ll_gd_rotated.nc
# 105 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20170825t095721-20170825t095901-000003-00C80B_ll_gd_rotated.nc
# 106 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200825t113334-20200825t113556-00003-1C85F_ll_gd_rotated.nc
# 107 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20200901t212522-20200901t212726-000003-02C081_ll_gd_rotated.nc
# 108 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190307t004754-20190307t005102-000003-01C845_ll_gd_rotated.nc
# 109 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201109t111723-20201109t111839-00003-5CB30_ll_gd_rotated.nc
# 110 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180803t142144-20180803t142259-00003-0444B_ll_gd_rotated.nc
# 111 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150803t202943-20150803t203347-00003-BDBFE_ll_gd_rotated.nc
# 112 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201102t220236-20201102t220406-000003-0417BC_ll_gd_rotated.nc
# 113 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190319t234935-20190319t235109-000003-01CE62_ll_gd_rotated.nc
# 114 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20141003t131421-20141003t131537-00003-E41DD_ll_gd_rotated.nc
# 115 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160912t212718-20160912t213122-00003-BDC5F_ll_gd_rotated.nc
# 116 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20130701t104119-20130701t104235-00003-79BFE_ll_gd_rotated.nc
# 117 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20160829t083147-20160829t083331-000003-014340_ll_gd_rotated.nc
# 118 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20130802t223244-20130802t223400-00003-822F0_ll_gd_rotated.nc
# 119 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201028t120710-20201028t120825-00003-5CB2D_ll_gd_rotated.nc
# 120 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190321t201403-20190321t201625-000003-01CF41_ll_gd_rotated.nc
# 121 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160902t035139-20160902t035544-00003-82CFF_ll_gd_rotated.nc
# 122 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190503t001255-20190503t001459-000003-01E3AE_ll_gd_rotated.nc
# 123 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190612t011725-20190612t011929-000003-01F595_ll_gd_rotated.nc
# 124 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20160904t163028-20160904t163208-000003-014658_ll_gd_rotated.nc
# 125 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20171014t193841-20171014t194046-000003-00DD36_ll_gd_rotated.nc
# 126 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20200803t231311-20200803t231426-000003-03E964_ll_gd_rotated.nc
# 127 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20160901t234439-20160901t234559-000003-01450E_ll_gd_rotated.nc
# 128 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190329t140231-20190329t140436-000003-02F9EC_ll_gd_rotated.nc
# 129 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190706t030714-20190706t030900-000003-03292B_ll_gd_rotated.nc
# 130 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20200922t101602-20200922t101906-000003-0402C5_ll_gd_rotated.nc
# 131 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190330t005718-20190330t010032-000003-02FA24_ll_gd_rotated.nc
# 132 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20191208t022442-20191208t022601-000003-024608_ll_gd_rotated.nc
# 133 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20200915t235233-20200915t235417-000003-02C6F9_ll_gd_rotated.nc
# 134 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20200921t194728-20200921t194822-000003-02C997_ll_gd_rotated.nc
# 135 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20191105t195730-20191105t195916-000003-03651B_ll_gd_rotated.nc
# 136 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140717t102721-20140717t102909-00003-350CF_ll_gd_rotated.nc
# 137 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180809t013708-20180809t013908-000003-02842F_ll_gd_rotated.nc
# 138 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160718t025234-20160718t025513-00003-63D6C_ll_gd_rotated.nc
# 139 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20121016t132633-20121016t132749-00003-52C09_ll_gd_rotated.nc
# 140 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20201008t091245-20201008t091425-000003-040AD1_ll_gd_rotated.nc
# 141 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20190830t224548-20190830t224705-000003-03435D_ll_gd_rotated.nc
# 142 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20180929t092736-20180929t092916-000003-017E09_ll_gd_rotated.nc
# 143 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20150926t155947-20150926t160044-000003-00B015_ll_gd_rotated.nc
# 144 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180829t075408-20180829t075612-000003-017011_ll_gd_rotated.nc
# 145 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180829t151005-20180829t151216-000003-01703D_ll_gd_rotated.nc
# 146 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140814t014651-20140814t014807-00003-E41D5_ll_gd_rotated.nc
# 147 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180929t020104-20180929t020308-000003-029C16_ll_gd_rotated.nc
# 148 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190311t024310-20190311t024514-000003-02F003_ll_gd_rotated.nc
# 149 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150830t154150-20150830t154305-00003-E0BF3_ll_gd_rotated.nc
# 150 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190223t202348-20190223t202552-000003-01C2E0_ll_gd_rotated.nc
# 151 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181025t203134-20181025t203308-000003-02A8D5_ll_gd_rotated.nc
# 152 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180912t081831-20180912t082017-000003-01765A_ll_gd_rotated.nc
# 153 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180727t202558-20180727t202902-000003-016188_ll_gd_rotated.nc
# 154 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20200827t000908-20200827t001138-000003-03F518_ll_gd_rotated.nc
# 155 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190306t135326-20190306t135533-000003-01C808_ll_gd_rotated.nc
# 156 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20200124t144415-20200124t144720-000003-038D72_ll_gd_rotated.nc
# 157 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170727t201017-20170727t201126-00003-0240B_ll_gd_rotated.nc
# 158 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160709t144141-20160709t144257-00003-E08D0_ll_gd_rotated.nc
# 159 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20120928t095127-20120928t095327-00003-BDBE0_ll_gd_rotated.nc
# 160 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190704t023228-20190704t023438-000003-01FF1E_ll_gd_rotated.nc
# 161 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181027t210308-20181027t210442-000003-018AC3_ll_gd_rotated.nc
# 162 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170730t202309-20170730t202548-00003-BDC95_ll_gd_rotated.nc
# 163 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160910t204800-20160910t204916-00003-562F5_ll_gd_rotated.nc
# 164 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20190323t213833-20190323t214017-000003-01D040_ll_gd_rotated.nc
# 165 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170804t211741-20170804t211857-00003-0B25E_ll_gd_rotated.nc
# 166 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200921t100325-20200921t100548-00003-5CB16_ll_gd_rotated.nc
# 167 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190207t020834-20190207t021051-000003-02DF33_ll_gd_rotated.nc
# 168 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180815t104101-20180815t104220-000003-02872E_ll_gd_rotated.nc
# 169 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20210118t144525-20210118t144726-000003-043E8B_ll_gd_rotated.nc
# 170 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150621t104002-20150621t104109-00003-2081D_ll_gd_rotated.nc
# 171 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180811t052613-20180811t052854-000003-0167F5_ll_gd_rotated.nc
# 172 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140805t093342-20140805t093535-00003-E41BC_ll_gd_rotated.nc
# 173 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201225t144526-20201225t144819-000003-04324A_ll_gd_rotated.nc
# 174 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180908t093806-20180908t094010-000003-029263_ll_gd_rotated.nc
# 175 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190216t072052-20190216t072256-000003-02E3FF_ll_gd_rotated.nc
# 176 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180303t020023-20180303t020327-000003-023BFA_ll_gd_rotated.nc
# 177 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180914t095035-20180914t095221-000003-029526_ll_gd_rotated.nc
# 178 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20200918t064225-20200918t064340-000003-02C7F6_ll_gd_rotated.nc
# 179 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20200902t235812-20200902t235927-000003-03F8BD_ll_gd_rotated.nc
# 180 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180902t022508-20180902t022712-000003-0171D9_ll_gd_rotated.nc
# 181 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20200802t231913-20200802t232034-000003-02B2DB_ll_gd_rotated.nc
# 182 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20181002t013418-20181002t013558-000003-017F30_ll_gd_rotated.nc
# 183 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150903t152310-20150903t152714-00003-F9957_ll_gd_rotated.nc
# 184 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181009t234305-20181009t234610-000003-02A153_ll_gd_rotated.nc
# 185 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180905t020104-20180905t020308-000003-0290CC_ll_gd_rotated.nc
# 186 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170908t220217-20170908t220421-000003-01EC26_ll_gd_rotated.nc
# 187 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140914t090541-20140914t090657-00003-E41D8_ll_gd_rotated.nc
# 188 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160926t093348-20160926t093714-000003-01509C_ll_gd_rotated.nc
# 189 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180103t145358-20180103t145513-000003-0220D9_ll_gd_rotated.nc
# 190 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20190905t214131-20190905t214336-000003-021B40_ll_gd_rotated.nc
# 191 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201024t215525-20201024t215748-00003-5CB2C_ll_gd_rotated.nc
# 192 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201029t205631-20201029t205758-000003-0415BC_ll_gd_rotated.nc
# 193 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20151021t152606-20151021t152722-00003-2B6FE_ll_gd_rotated.nc
# 194 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20210122t025113-20210122t025228-000003-030207_ll_gd_rotated.nc
# 195 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181007t023405-20181007t023610-000003-029FF5_ll_gd_rotated.nc
# 196 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160708t024536-20160708t024652-00003-E08D0_ll_gd_rotated.nc
# 197 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20200921t075828-20200921t075920-000003-04022D_ll_gd_rotated.nc
# 198 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20190328t005221-20190328t005444-00003-AB1C7_ll_gd_rotated.nc
# 199 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20201004t142803-20201004t143007-000003-02CF68_ll_gd_rotated.nc
# 200 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150905t033940-20150905t034345-00003-F99C1_ll_gd_rotated.nc
# 201 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20190314t160552-20190314t160801-000003-01CBEE_ll_gd_rotated.nc
# 202 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190803t032245-20190803t032443-000003-020C12_ll_gd_rotated.nc
# 203 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20200920t000909-20200920t001024-000003-040179_ll_gd_rotated.nc
# 204 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150906t185705-20150906t185821-00003-E0C03_ll_gd_rotated.nc
# 205 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180901t032311-20180901t032613-000003-01715C_ll_gd_rotated.nc
# 206 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20191126t071356-20191126t071511-000003-036F6F_ll_gd_rotated.nc
# 207 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20191024t202109-20191024t202332-00003-3EAE7_ll_gd_rotated.nc
# 208 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180912t091024-20180912t091140-00003-202A6_ll_gd_rotated.nc
# 209 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20171008t204743-20171008t204859-00003-2B6FE_ll_gd_rotated.nc
# 210 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190303t133123-20190303t133257-000003-01C6A0_ll_gd_rotated.nc
# 211 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140717t225349-20140717t225504-00003-BDBE0_ll_gd_rotated.nc
# 212 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20160926t214317-20160926t214526-000003-0150DC_ll_gd_rotated.nc
# 213 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180812t172848-20180812t173053-000003-0285E5_ll_gd_rotated.nc
# 214 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190904t133932-20190904t134121-000003-0345B8_ll_gd_rotated.nc
# 215 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190731t034721-20190731t034910-000003-033442_ll_gd_rotated.nc
# 216 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201003t141913-20201003t142136-00003-3268A_ll_gd_rotated.nc
# 217 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180907t213205-20180907t213409-000003-029225_ll_gd_rotated.nc
# 218 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200916t091217-20200916t091548-00003-250A5_ll_gd_rotated.nc
# 219 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160904t223153-20160904t223504-000003-01467A_ll_gd_rotated.nc
# 220 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180614t131412-20180614t131527-000003-026B91_ll_gd_rotated.nc
# 221 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180907t041406-20180907t041610-000003-017415_ll_gd_rotated.nc
# 222 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20191025t081225-20191025t081426-000003-023199_ll_gd_rotated.nc
# 223 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180819t032959-20180819t033303-000003-0288F7_ll_gd_rotated.nc
# 224 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201030t211604-20201030t211719-00003-5CB2D_ll_gd_rotated.nc
# 225 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181010t114907-20181010t115212-000003-02A192_ll_gd_rotated.nc
# 226 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160826t133953-20160826t134056-000003-0141F0_ll_gd_rotated.nc
# 227 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180818t150300-20180818t150604-000003-0288C3_ll_gd_rotated.nc
# 228 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20161006t223232-20161006t223348-00003-E08E4_ll_gd_rotated.nc
# 229 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180308t012234-20180308t012539-000003-011FE5_ll_gd_rotated.nc
# 230 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190906t141103-20190906t141249-000003-021B95_ll_gd_rotated.nc
# 231 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180831t203802-20180831t204009-000003-028EDA_ll_gd_rotated.nc
# 232 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150715t144252-20150715t144408-00003-E0BE7_ll_gd_rotated.nc
# 233 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160721t153232-20160721t153512-00003-63D78_ll_gd_rotated.nc
# 234 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20130929t224119-20130929t224235-00003-28A04_ll_gd_rotated.nc
# 235 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20161009t223946-20161009t224047-000003-0041D0_ll_gd_rotated.nc
# 236 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180930t015309-20180930t015513-000003-017E57_ll_gd_rotated.nc
# 237 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160830t094412-20160830t094716-000003-0143C4_ll_gd_rotated.nc
# 238 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170819t140047-20170819t140203-00003-2B711_ll_gd_rotated.nc
# 239 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180831t033103-20180831t033408-000003-028E87_ll_gd_rotated.nc
# 240 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140807t155748-20140807t155950-00003-E41BB_ll_gd_rotated.nc
# 241 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181005t015910-20181005t020215-000003-018087_ll_gd_rotated.nc
# 242 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150516t203538-20150516t203654-00003-BDBFF_ll_gd_rotated.nc
# 243 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180808t082357-20180808t082552-000003-016699_ll_gd_rotated.nc
# 244 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160829t022730-20160829t023009-00003-82CF2_ll_gd_rotated.nc
# 245 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20141019t044431-20141019t044547-00003-E0949_ll_gd_rotated.nc
# 246 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180822t042043-20180822t042200-00003-117D9_ll_gd_rotated.nc
# 247 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190308t142434-20190308t142620-000003-02EEA4_ll_gd_rotated.nc
# 248 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180818t083657-20180818t084001-000003-016B1D_ll_gd_rotated.nc
# 249 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180908t151005-20180908t151121-00003-2B6FE_ll_gd_rotated.nc
# 250 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20140907t014846-20140907t015037-00003-E41D5_ll_gd_rotated.nc
# 251 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20190906t094312-20190906t094536-00003-1CBF4_ll_gd_rotated.nc
# 252 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180726t203604-20180726t203909-000003-027E26_ll_gd_rotated.nc
# 253 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180207t131831-20180207t132131-000003-01120C_ll_gd_rotated.nc
# 254 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160831t031520-20160831t031712-000003-014425_ll_gd_rotated.nc
# 255 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180807t083104-20180807t083409-000003-028367_ll_gd_rotated.nc
# 256 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201003t022600-20201003t022817-000003-04082E_ll_gd_rotated.nc
# 257 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20200728t050249-20200728t050456-000003-02B05B_ll_gd_rotated.nc
# 258 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181008t235029-20181008t235233-000003-01824C_ll_gd_rotated.nc
# 259 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180901t151418-20180901t151534-00003-2B6FE_ll_gd_rotated.nc
# 260 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20191008t203040-20191008t203250-000003-0356ED_ll_gd_rotated.nc
# 261 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160712t022824-20160712t022940-00003-2B711_ll_gd_rotated.nc
# 262 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180913t105836-20180913t110059-00003-212E5_ll_gd_rotated.nc
# 263 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20201103t103118-20201103t103249-000003-041800_ll_gd_rotated.nc
# 264 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20170923t104349-20170923t104554-000003-00D45F_ll_gd_rotated.nc
# 265 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160825t093014-20160825t093130-00003-BDC5F_ll_gd_rotated.nc
# 266 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190221t195241-20190221t195445-000003-02E6EA_ll_gd_rotated.nc
# 267 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181006t140456-20181006t140700-000003-029FBE_ll_gd_rotated.nc
# 268 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20201008t000702-20201008t000846-000003-02D0FE_ll_gd_rotated.nc
# 269 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180910t155203-20180910t155319-00003-2B6FE_ll_gd_rotated.nc
# 270 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20200918t081938-20200918t082143-000003-02C801_ll_gd_rotated.nc
# 271 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20151023t124550-20151023t124825-00003-2D9AB_ll_gd_rotated.nc
# 272 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20141101t123041-20141101t123157-00003-E41DD_ll_gd_rotated.nc
# 273 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181009t142906-20181009t143110-000003-02A122_ll_gd_rotated.nc
# 274 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180905t034104-20180905t034309-000003-0290D7_ll_gd_rotated.nc
# 275 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190323t104523-20190323t104727-000003-01D003_ll_gd_rotated.nc
# 276 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170908t105352-20170908t105502-00003-32A96_ll_gd_rotated.nc
# 277 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20180911t204751-20180911t204937-000003-017624_ll_gd_rotated.nc
# 278 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160904t092033-20160904t092333-000003-014632_ll_gd_rotated.nc
# 279 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20191023t083016-20191023t083348-00003-3E0AE_ll_gd_rotated.nc
# 280 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20141101t205327-20141101t205443-00003-E41DB_ll_gd_rotated.nc
# 281 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20191207t022100-20191207t022324-00003-5DA4E_ll_gd_rotated.nc
# 282 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20180308t012408-20180308t012739-00003-9C4C8_ll_gd_rotated.nc
# 283 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181222t132215-20181222t132419-000003-02C6B3_ll_gd_rotated.nc
# 284 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20191107t193942-20191107t194146-000003-036628_ll_gd_rotated.nc
# 285 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200901t213245-20200901t213508-00003-1BD2E_ll_gd_rotated.nc
# 286 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20180904t083405-20180904t083710-000003-029075_ll_gd_rotated.nc
# 287 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180616t004702-20180616t004817-000003-026C31_ll_gd_rotated.nc
# 288 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150803t152928-20150803t153044-00003-E0BF0_ll_gd_rotated.nc
# 289 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170831t080618-20170831t081021-00003-68AA5_ll_gd_rotated.nc
# 290 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20181026t090105-20181026t090239-000003-02A914_ll_gd_rotated.nc
# 291 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160923t222132-20160923t222431-000003-014F7C_ll_gd_rotated.nc
# 292 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201009t090404-20201009t090628-00003-3520D_ll_gd_rotated.nc
# 293 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160825t093033-20160825t093136-00003-E08D6_ll_gd_rotated.nc
# 294 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20200904t210200-20200904t210504-000003-03F9A9_ll_gd_rotated.nc
# 295 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181011t142009-20181011t142213-000003-018371_ll_gd_rotated.nc
# 296 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200919t221407-20200919t221523-00003-5CB16_ll_gd_rotated.nc
# 297 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20181006t095207-20181006t095411-000003-01811B_ll_gd_rotated.nc
# 298 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160829t214021-20160829t214342-000003-01438B_ll_gd_rotated.nc
# 299 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20150821t214623-20150821t214717-00003-E0BF1_ll_gd_rotated.nc
# 300 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20171028t092802-20171028t092921-000003-00E2ED_ll_gd_rotated.nc
# 301 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170906t211519-20170906t211921-00003-68AA5_ll_gd_rotated.nc
# 302 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-iw-owi-cm-20190829t102127-20190829t102221-000003-0217F3_ll_gd_rotated.nc
# 303 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180822t210038-20180822t210213-000003-028AA9_ll_gd_rotated.nc
# 304 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20190920t221952-20190920t222132-000003-034DF5_ll_gd_rotated.nc
# 305 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160923t221151-20160923t221415-00003-26FB4_ll_gd_rotated.nc
# 306 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170922t104537-20170922t104653-00003-BDC95_ll_gd_rotated.nc
# 307 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170829t002530-20170829t002710-000003-01E74D_ll_gd_rotated.nc
# 308 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20170918t220558-20170918t221002-00003-32A96_ll_gd_rotated.nc
# 309 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20190901t110302-20190901t110526-00003-193BB_ll_gd_rotated.nc
# 310 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20141004t210600-20141004t210715-00003-BDBE0_ll_gd_rotated.nc
# 311 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190427t123324-20190427t123528-000003-03095B_ll_gd_rotated.nc
# 312 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20170903t102458-20170903t102552-000003-01E9AD_ll_gd_rotated.nc
# 313 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20190322t214643-20190322t214850-000003-02F65C_ll_gd_rotated.nc
# 314 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20200821t221932-20200821t222047-000003-03F28D_ll_gd_rotated.nc
# 315 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160902t082858-20160902t083120-000003-014532_ll_gd_rotated.nc
# 316 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20180823t093905-20180823t093959-000003-028AED_ll_gd_rotated.nc
# 317 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20160925t092440-20160925t092703-00003-28142_ll_gd_rotated.nc
# 318 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20201001t133839-20201001t133955-00003-3268A_ll_gd_rotated.nc
# 319 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-iw-owi-cm-20200803t100117-20200803t100257-000003-03E924_ll_gd_rotated.nc
# 320 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/rs2--owi-cm-20200831t094052-20200831t094316-00003-1BD2E_ll_gd_rotated.nc
# 321 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1a-ew-owi-cm-20160901t202925-20160901t203108-000003-0144F0_ll_gd_rotated.nc
# 322 =>     /home/arthur/data/cyclobs/rotated_files/clean_dataset/s1b-ew-owi-cm-20190309t141317-20190309t141622-000003-01C976_ll_gd_rotated.nc
# Number of TCs in each categories:
# Storm:   100
# Cat. 1 : 78
# Cat. 2 : 41
# Cat. 3 : 52
# Cat. 4 : 34
# Cat. 5 : 17

# %%
a = np.array([0.8, 0.9, 0.9, 1.1, 1.2, 1.5, 1.7, 1.9, 2.1, 2.3])
b = [np.argwhere(a > i)[0] for i in range(0, 3)]
b
# Out:
# [array([0]), array([3]), array([8])]

# %%
cat = np.array(ds['current_category'])
print(cat)
test = str(cat)
aa = [i for i in test]
print(aa)
# Out:
# storm
# ['s', 't', 'o', 'r', 'm']

# %%
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                             (x: 1000, y: 1000, lon: 1000, lat: 1000)
# Coordinates:
#     x_coords                            (x, y) int64 ...
#     y_coords                            (x, y) int64 ...
#     r_polar                             (x, y) float64 707.1 706.4 ... 705.7
#     theta                               (x, y) float64 5.498 5.497 ... 2.356
#     lon_coords                          (lon, lat) float64 ...
#     lat_coords                          (lon, lat) float64 ...
# Dimensions without coordinates: x, y, lon, lat
# Data variables: (12/40)
#     wind_from_direction                 (x, y) float32 ...
#     nrcs_detrend_cross                  (x, y) float32 ...
#     incidence_angle                     (x, y) float32 ...
#     wind_streaks_orientation_stddev     (x, y) float32 ...
#     nrcs_detrend_co                     (x, y) float32 ...
#     mask_flag                           (x, y) float32 ...
#     ...                                  ...
#     current_category                    <U5 'storm'
#     vmax_ms                             int64 ...
#     sid                                 object ...
#     cyclone_name                        object ...
#     lon_ref                             float64 ...
#     lat_ref                             float64 -38.52
# Attributes:
#     Track source file:  bsh172019.dat
#     SAR source file:    s1b-ew-owi-cm-20190309t141317-20190309t141622-000003-...

# %%
r_star = np.linspace(0., 8., num=321)
r_star
# Out:
# array([0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#        0.225, 0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425,
#        0.45 , 0.475, 0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 ,
#        0.675, 0.7  , 0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875,
#        0.9  , 0.925, 0.95 , 0.975, 1.   , 1.025, 1.05 , 1.075, 1.1  ,
#        1.125, 1.15 , 1.175, 1.2  , 1.225, 1.25 , 1.275, 1.3  , 1.325,
#        1.35 , 1.375, 1.4  , 1.425, 1.45 , 1.475, 1.5  , 1.525, 1.55 ,
#        1.575, 1.6  , 1.625, 1.65 , 1.675, 1.7  , 1.725, 1.75 , 1.775,
#        1.8  , 1.825, 1.85 , 1.875, 1.9  , 1.925, 1.95 , 1.975, 2.   ,
#        2.025, 2.05 , 2.075, 2.1  , 2.125, 2.15 , 2.175, 2.2  , 2.225,
#        2.25 , 2.275, 2.3  , 2.325, 2.35 , 2.375, 2.4  , 2.425, 2.45 ,
#        2.475, 2.5  , 2.525, 2.55 , 2.575, 2.6  , 2.625, 2.65 , 2.675,
#        2.7  , 2.725, 2.75 , 2.775, 2.8  , 2.825, 2.85 , 2.875, 2.9  ,
#        2.925, 2.95 , 2.975, 3.   , 3.025, 3.05 , 3.075, 3.1  , 3.125,
#        3.15 , 3.175, 3.2  , 3.225, 3.25 , 3.275, 3.3  , 3.325, 3.35 ,
#        3.375, 3.4  , 3.425, 3.45 , 3.475, 3.5  , 3.525, 3.55 , 3.575,
#        3.6  , 3.625, 3.65 , 3.675, 3.7  , 3.725, 3.75 , 3.775, 3.8  ,
#        3.825, 3.85 , 3.875, 3.9  , 3.925, 3.95 , 3.975, 4.   , 4.025,
#        4.05 , 4.075, 4.1  , 4.125, 4.15 , 4.175, 4.2  , 4.225, 4.25 ,
#        4.275, 4.3  , 4.325, 4.35 , 4.375, 4.4  , 4.425, 4.45 , 4.475,
#        4.5  , 4.525, 4.55 , 4.575, 4.6  , 4.625, 4.65 , 4.675, 4.7  ,
#        4.725, 4.75 , 4.775, 4.8  , 4.825, 4.85 , 4.875, 4.9  , 4.925,
#        4.95 , 4.975, 5.   , 5.025, 5.05 , 5.075, 5.1  , 5.125, 5.15 ,
#        5.175, 5.2  , 5.225, 5.25 , 5.275, 5.3  , 5.325, 5.35 , 5.375,
#        5.4  , 5.425, 5.45 , 5.475, 5.5  , 5.525, 5.55 , 5.575, 5.6  ,
#        5.625, 5.65 , 5.675, 5.7  , 5.725, 5.75 , 5.775, 5.8  , 5.825,
#        5.85 , 5.875, 5.9  , 5.925, 5.95 , 5.975, 6.   , 6.025, 6.05 ,
#        6.075, 6.1  , 6.125, 6.15 , 6.175, 6.2  , 6.225, 6.25 , 6.275,
#        6.3  , 6.325, 6.35 , 6.375, 6.4  , 6.425, 6.45 , 6.475, 6.5  ,
#        6.525, 6.55 , 6.575, 6.6  , 6.625, 6.65 , 6.675, 6.7  , 6.725,
#        6.75 , 6.775, 6.8  , 6.825, 6.85 , 6.875, 6.9  , 6.925, 6.95 ,
#        6.975, 7.   , 7.025, 7.05 , 7.075, 7.1  , 7.125, 7.15 , 7.175,
#        7.2  , 7.225, 7.25 , 7.275, 7.3  , 7.325, 7.35 , 7.375, 7.4  ,
#        7.425, 7.45 , 7.475, 7.5  , 7.525, 7.55 , 7.575, 7.6  , 7.625,
#        7.65 , 7.675, 7.7  , 7.725, 7.75 , 7.775, 7.8  , 7.825, 7.85 ,
#        7.875, 7.9  , 7.925, 7.95 , 7.975, 8.   ])

# %%
r2 = 1.002355765
st = 'R^2 = {:.2f}'.format(r2)

# %%
a = [2, 2, 2]
b = [1, 1, 1]
np.subtract(a, b)
# Out:
# array([1, 1, 1])

# %%
def get_std(x, n):
    gap = (x - np.divide(x, n)) ** 2
    std = np.divide(gap, n)
    return std

x = [1, 2, 3]
n = [1, 1, 1]
print(get_std(x, n))
print(np.std(x))
# Out:
# [0. 0. 0.]
# 0.816496580927726

# %%
a = np.expand_dims(np.array([1, 1, 1]), axis=0)
b = np.expand_dims(np.array([1, 3, 1]), axis=0)
b2 = np.expand_dims(np.array([1, 4, 1]), axis=0)
c = np.append(a, b, axis=0)
c = np.append(c, b2, axis=0)
print(c)
print(c.shape)

def get_mean_std(x, n):
    masked = np.ma.masked_where(n == 0, x)
    mean   = np.ma.mean(masked, axis=0)
    std    = np.ma.std(masked, axis=0)
    return mean, std

print(get_mean_std(c, np.array([[1, 1, 1], [1, 1, 1], [1, 1, 1]])))

# mean_diff = np.divide(np.sum(DIFF[i][profile], axis=0), NB_CAT[i][profile])
# Out:
# [[1 1 1]
#  [1 3 1]
#  [1 4 1]]
# (3, 3)
# (masked_array(data=[1.        , 2.66666667, 1.        ],
#              mask=False,
#        fill_value=1e+20), masked_array(data=[0.0, 1.247219128924647, 0.0],
#              mask=[False, False, False],
#        fill_value=1e+20))
